# %%
class LRScratch:
    # Constructor
    def __init__(self):
        # Assign initial value to m , b
        self.m=None
        self.b=None
    
    # Method fit to train model
    def fit(self,X_train,y_train):
        num = 0
        den = 0
        
        for i in range(X_train.shape[0]):
            
            num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))
        
        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
        print('m ->' , self.m)
        print('b ->' , self.b) 
    
    # Prediction
    def predict(self,X_test):
        print('input ->' , X_test)
        
        return self.m * X_test + self.b

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../../../DataBox/placement_package.csv')

# %%
# IO .values for numpy

X = df.iloc[:,0].values
y = df.iloc[:,1].values

# TTS
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
# Create Object of my class

lr = LRScratch()

lr.fit(X_train,y_train)

print('Output -> ' , lr.predict(X_test[0]))
# Out:
# m -> 0.5579519734250721
# b -> -0.8961119222429152
# input -> 8.58
# Output ->  3.891116009744203
