# %%
from pandas_profiling import ProfileReport

import pandas as pd

# %%
df = pd.read_csv('../DataBox/titanic.csv',index_col=0)

prof = ProfileReport(df)
prof.to_file(output_file = '../Output/output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
