# %%
import pickle
import pandas as pd
import numpy as np

# %%
pipe = pickle.load(open('../../PickelFiles/pipe.pkl','rb'))

# %%
# Assume user input
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# Creating PD dataframe as it was the input of our pipeline
test_df = pd.DataFrame(test_input, columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])

prediction = pipe.predict(test_df)
